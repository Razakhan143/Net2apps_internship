# %%
from TestCases.Rating_Scale_Reverse import rating_scale_reverse
reverse=rating_scale_reverse()
driver, data_list=reverse.rating_scale_reverse()
# Out:
# ============= Scale 1: ztest new object_7 =============
# ============= Scale 2: ztest new object_11 =============
# ============= Scale 3: ztest new object_19 =============
# ============= Scale 4: ztest new object_23 =============
# ============= Scale 5: ztest new object_27 =============
# ============= Scale 6: ztest new object_31 =============
# ============= Scale 7: ztest new object_35 =============
# ============= Scale 8: ztest new object_5 =============
# ============= Scale 9: ztest new object_17 =============
# ============= Scale 10: ztest new object_21 =============
# ============= Scale 11: ztest new object_29 =============
# ============= Scale 12: ztest new object_33 =============
# ============= Scale 13: ztest new object_1 =============
# ============= Scale 14: Default Scale =============
# ============= Scale 15: ztest new object gg =============
# ============= Scale 16: Proficiency Level Scale20260618 =============
# ...

# %%
from Controller.controllers_rating_scale import rating_scale_fill_sheet_controller
fill_sheet=rating_scale_fill_sheet_controller()
fill_sheet.rating_scale_processing_fill_controller(data_list)
fill_sheet.rating_scale_description_fill_controller(data_list)
fill_sheet.rating_scale_scores_fill_controller(data_list)
# Out:
# Clearing data from row 4 to 173 in the worksheet.

# %%
from importlib import reload
import TestCases.Rating_Scale_Validate
reload(TestCases.Rating_Scale_Validate)
from TestCases.Rating_Scale_Validate import rating_scale_validation
val=rating_scale_validation()
val.validate_description_section(data_list)
# val.validate_scores_section(data_list)
# Out:
# validating description : rating scale description with rating scale description and the are same: True
# validating description : rating scale description with rating scale description and the are same: True
# validating description : rating scale description with rating scale description and the are same: True
# validating description : rating scale description with rating scale description and the are same: True
# validating description : rating scale description with rating scale description and the are same: True
# validating description : rating scale description with rating scale description and the are same: True
# validating description : rating scale description with rating scale description and the are same: True
# validating description : rating scale description with rating scale description and the are same: True
# validating description : rating with rating scale description and the are same: False
# ...

# %%
from TestCases.automation_rating_scale import rating_scale_automation
auto=rating_scale_automation()
auto.automate(data_list, driver)
# Out:
# Rating scale: ztest new object_6 exists in the web page at index: 0
# Rating scale: ztest new object_12 exists in the web page at index: 1
# Rating scale: ztest new object_18 exists in the web page at index: 2
# Rating scale: ztest new object_22 exists in the web page at index: 3
# Rating scale: ztest new object_28 exists in the web page at index: 4
# Rating scale: ztest new object_34 exists in the web page at index: 5
# Rating scale: ztest new object_7 exists in the web page at index: 6
# Rating scale: ztest new object_11 exists in the web page at index: 7
# Rating scale: ztest new object_15 exists in the web page at index: 8
# Rating scale: ztest new object_19 exists in the web page at index: 9
# Rating scale: ztest new object_23 exists in the web page at index: 10
# Rating scale: ztest new object_27 exists in the web page at index: 11
# Rating scale: ztest new object_31 exists in the web page at index: 12
# Rating scale: ztest new object_35 exists in the web page at index: 13
# ...
