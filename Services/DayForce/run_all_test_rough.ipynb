# %%
# importing the required modules for the test cases
from TestCases.Pay_Category_Reverse import  Pay_Category_Reverse
from Controllers.Pay_Category_Load_fill_Controller import  Pay_Category_fill_controller

# %%
#============== Performing the Reverse test case for Pay Category ==============
pay_category_reverse = Pay_Category_Reverse()
web_models, groups, driver = pay_category_reverse.Pay_Category_Reverse()
# Out:
# Login Successful
# Pay Category Reverse Completed

# %%
#============== Reverse Completed ===================

#============== Performing the Fill test case for Pay Category ==============
pay_category_fill = Pay_Category_fill_controller()
pay_category_fill.pay_category_fill_controller(web_models)

#============== Fill Completed ===================
# Out:
# Clearing data from row 4 to 259 in the worksheet.
# Pay Category Fill Completed

# %%
from importlib import reload
import TestCases.Pay_Category_Validate
reload(TestCases.Pay_Category_Validate)
from TestCases.Pay_Category_Validate import  Pay_Category_Validation
# #============== Performing the Validation test case for Pay Category ==============
pay_category_validation = Pay_Category_Validation()
pay_category_validation.validate_pay_category(web_models)
# Out:
# 259
# Validating Pay Category ID: 10113, with Web Model id:10113 and the object is this si new
# Validation Completed

# %%
#============== Validation Completed ===================
import Utilites.Pay_Category_Common_Helper
reload(Utilites.Pay_Category_Common_Helper)
import TestCases.Pay_Category_Automate
reload(TestCases.Pay_Category_Automate)
from TestCases.Pay_Category_Automate import  Pay_Category_Automate
#============== Performing the Automate test case for Pay Category ==============
pay_category_automate = Pay_Category_Automate()
pay_category_automate.automate_pay_category(driver, web_models, groups)

# #============== Automation Completed ===================
# Out:
# No pay category found for object so, creating new one: this si new
# object updated successfully
# Automation Completed for Pay Category

# %%
id.item_id
# Out:
# 129
